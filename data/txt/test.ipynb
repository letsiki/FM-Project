# %%
import pandas as pd
import os

# %%
df = pd.read_csv('data/roles/csv/box_to_box_midfielder.csv')

# %%
# def calculate_correlations(df):
#     # Ensure 'Av Rat' column exists
#     if 'Av Rat' not in df.columns:
#         raise ValueError("'Av Rat' column is not present in the DataFrame")

#     # Create a copy of the DataFrame to avoid modifying the original
#     df_copy = df.copy()

#     # Clean and convert 'Av Rat' column to float
#     try:
#         df_copy['Av Rat'] = df_copy['Av Rat'].str.strip()  # Remove any leading/trailing whitespace
#     except:
#         print('Av Rat is not a string stripping operation skipped')
#     df_copy['Av Rat'] = pd.to_numeric(df_copy['Av Rat'], errors='coerce')  # Convert to numeric, set invalid parsing as NaN

#     # Drop rows where 'Av Rat' could not be converted (if any)
#     df_copy = df_copy.dropna(subset=['Av Rat'])

#     # Get the columns from 'Wor' to the end
#     start_col = 'Wor'
#     if start_col not in df_copy.columns:
#         raise ValueError(f"'{start_col}' column is not present in the DataFrame")

#     start_index = df_copy.columns.get_loc(start_col)
#     selected_columns = df_copy.columns[start_index:]

#     # Filter int64 columns only
#     numeric_columns = df_copy[selected_columns].select_dtypes(include=['int64', 'float64']).columns

#     # Calculate correlations with 'Av Rat'
#     correlations = df_copy[numeric_columns].corrwith(df_copy['Av Rat'])

#     return correlations.sort_values(ascending=False)

def calculate_correlations(df):

    # Convert the 'Av Rat' column to numeric values, forcing errors to NaN and then dropping those rows
    df['Av Rat'] = pd.to_numeric(df['Av Rat'], errors='coerce')
    
    # Drop rows where 'Av Rat' could not be converted to a number (NaN values)
    df = df.dropna(subset=['Av Rat'])
    
    # df = df.loc[df['Av Rat'].between(6, 8)]  

    # Check if there are enough rows
    if len(df) < 150:
        print("Not enough data for a statistically safe calculation. At least 30 rows are recommended.")
        return
    
    # Initialize an empty dictionary to store correlation values
    correlations = {}
    
    # Calculate the correlation of the second column with each column from the fifth to the end
    for col in df.columns[4:-2]:
        correlations[col] = df['Av Rat'].corr(df[col])
    
    # Sort the correlations dictionary by value in descending order
    sorted_correlations = sorted(correlations.items(), key=lambda x: x[1], reverse=True)
    
    # Print the sorted correlations
    for col, corr in sorted_correlations:
        print(f"{col}: {corr:.2f}")

# # Example usage
# # Assuming df is already defined and loaded with the necessary data
# correlations = calculate_correlations(df)
# print(correlations)
# print(type(correlations))

def process_csv_files(directory):
    """
    Process CSV files in the specified directory that have at least 100 rows.
    
    Args:
        directory (str): The path to the directory containing CSV files.
    """
    # List all CSV files in the directory
    csv_files = [f for f in os.listdir(directory) if f.endswith('.csv')]
    
    for csv_file in csv_files:
        file_path = os.path.join(directory, csv_file)
        df = pd.read_csv(file_path)  

        print(f"Processing {csv_file}...")
        print(f"Top correlations in {csv_file}:")
        correlations = calculate_correlations(df)

# Define the directory containing the CSV files
csv_directory = 'data/roles/csv/'

# Call the function to process the CSV files
process_csv_files(csv_directory)
# Out:
# Processing advanced_forward.csv...
# Top correlations in advanced_forward.csv:
# Cons: 0.24
# Pac: 0.21
# OtB: 0.14
# Sta: 0.14
# Pos: 0.13
# Tea: 0.13
# Agi: 0.13
# Cor: 0.12
# Bra: 0.12
# Pres: 0.12
# Cnt: 0.11
# Dec: 0.11
# Vis: 0.11
# Wor: 0.10
# Nat: 0.09
# Lon: 0.08
# Acc: 0.07
# Fin: 0.07
# Prof: 0.07
# Hea: 0.07
# Pas: 0.07
# Dri: 0.06
# Pen: 0.06
# Bal: 0.06
# Fre: 0.06
# L Th: 0.06
# Amb: 0.06
# Fla: 0.06
# Cmd: 0.06
# Spor: 0.05
# Str: 0.05
# Ldr: 0.05
# Cmp: 0.05
# Jum: 0.05
# Dirt: 0.04
# Ant: 0.04
# Fir: 0.03
# Aer: 0.02
# Ecc: 0.02
# Agg: 0.01
# Cont: 0.01
# Tec: 0.01
# 1v1: 0.00
# Cro: 0.00
# Inj Pr: -0.00
# Com: -0.00
# TRO: -0.01
# Temp: -0.01
# Loy: -0.01
# Mar: -0.02
# Kic: -0.03
# Imp M: -0.04
# Thr: -0.04
# Han: -0.04
# Tck: -0.05
# Det: -0.06
# Ref: -0.10
# Pun: -0.13
# Processing advanced_playmaker.csv...
# Top correlations in advanced_playmaker.csv:
# Agi: 0.33
# Dri: 0.32
# Pas: 0.29
# Tea: 0.29
# Sta: 0.28
# Cor: 0.28
# Fir: 0.28
# Str: 0.27
# Cro: 0.27
# Bal: 0.27
# Ant: 0.24
# Tec: 0.23
# Cnt: 0.22
# Lon: 0.22
# Bra: 0.22
# Fre: 0.22
# Cmp: 0.21
# Vis: 0.20
# Pen: 0.20
# Fin: 0.20
# OtB: 0.20
# Pac: 0.19
# Fla: 0.19
# Pos: 0.19
# Acc: 0.18
# Wor: 0.18
# Cons: 0.18
# Hea: 0.17
# Mar: 0.15
# Tck: 0.14
# L Th: 0.13
# Det: 0.13
# 1v1: 0.11
# Nat: 0.09
# Dec: 0.08
# Jum: 0.08
# Imp M: 0.07
# Dirt: 0.06
# Han: 0.05
# TRO: 0.04
# Ldr: 0.03
# Amb: 0.03
# Spor: 0.03
# Prof: 0.01
# Inj Pr: -0.01
# Ref: -0.02
# Com: -0.02
# Pres: -0.02
# Kic: -0.04
# Ecc: -0.04
# Cmd: -0.05
# Pun: -0.05
# Cont: -0.06
# Thr: -0.07
# Aer: -0.08
# Loy: -0.08
# Temp: -0.12
# Agg: -0.16
# Processing anchor.csv...
# Top correlations in anchor.csv:
# Cons: 0.36
# Cro: 0.33
# Dri: 0.32
# Pas: 0.27
# Hea: 0.27
# Tec: 0.26
# Pos: 0.25
# Mar: 0.25
# Str: 0.25
# Cnt: 0.24
# Tea: 0.24
# Vis: 0.23
# Bra: 0.22
# Lon: 0.21
# Cmp: 0.20
# OtB: 0.19
# Sta: 0.18
# Agg: 0.18
# Pen: 0.16
# Prof: 0.15
# Fla: 0.15
# Loy: 0.15
# Ldr: 0.15
# Cmd: 0.14
# Dec: 0.13
# Imp M: 0.13
# Bal: 0.13
# Nat: 0.12
# Jum: 0.11
# Amb: 0.11
# Spor: 0.10
# Ant: 0.10
# Pac: 0.10
# L Th: 0.08
# Agi: 0.07
# Fir: 0.07
# Thr: 0.06
# Fin: 0.06
# Dirt: 0.06
# Cont: 0.05
# Pres: 0.05
# Det: 0.05
# Acc: 0.05
# Han: 0.03
# 1v1: 0.02
# Aer: 0.01
# Ref: 0.00
# Wor: -0.00
# Fre: -0.01
# Ecc: -0.01
# Cor: -0.01
# TRO: -0.02
# Tck: -0.02
# Temp: -0.03
# Kic: -0.04
# Inj Pr: -0.05
# Pun: -0.07
# Com: -0.11
# Processing attacking_midfielder.csv...
# Top correlations in attacking_midfielder.csv:
# Wor: 0.30
# Pac: 0.28
# Sta: 0.28
# Cons: 0.27
# Acc: 0.26
# Dri: 0.23
# Bal: 0.23
# Prof: 0.21
# Pas: 0.21
# Tea: 0.21
# Agi: 0.20
# Str: 0.20
# Cnt: 0.19
# Vis: 0.17
# Lon: 0.14
# Tck: 0.12
# Det: 0.12
# OtB: 0.12
# Bra: 0.12
# Tec: 0.11
# Fir: 0.11
# Amb: 0.10
# Ant: 0.10
# Fin: 0.10
# Temp: 0.10
# Com: 0.10
# Cmp: 0.10
# Spor: 0.10
# Cro: 0.10
# Pres: 0.09
# Mar: 0.09
# 1v1: 0.09
# Kic: 0.09
# Cor: 0.08
# Thr: 0.07
# Nat: 0.07
# Fre: 0.06
# Fla: 0.06
# L Th: 0.06
# Pen: 0.05
# Jum: 0.05
# Hea: 0.05
# Pos: 0.05
# Ecc: 0.03
# Agg: 0.03
# Imp M: 0.02
# Dec: 0.02
# Loy: 0.02
# Pun: 0.02
# Ldr: -0.00
# Ref: -0.02
# Cmd: -0.02
# Dirt: -0.03
# Aer: -0.04
# TRO: -0.05
# Han: -0.09
# Cont: -0.11
# Inj Pr: -0.13
# Processing ball_playing_defender.csv...
# Top correlations in ball_playing_defender.csv:
# Cons: 0.29
# Jum: 0.18
# Pos: 0.11
# Det: 0.10
# Nat: 0.10
# Vis: 0.09
# Dirt: 0.09
# Hea: 0.08
# Str: 0.07
# Cmp: 0.05
# Fir: 0.05
# Fla: 0.05
# Pas: 0.04
# Dri: 0.03
# Temp: 0.03
# Ant: 0.03
# Han: 0.03
# Agi: 0.02
# Sta: 0.02
# Agg: 0.02
# Dec: 0.02
# Prof: 0.01
# Thr: 0.01
# Acc: 0.01
# Pen: 0.01
# Tck: 0.00
# Pun: 0.00
# Bal: 0.00
# Bra: 0.00
# Pac: -0.00
# Amb: -0.00
# Cro: -0.00
# Cmd: -0.00
# Tec: -0.00
# Wor: -0.00
# Imp M: -0.01
# Tea: -0.01
# Cnt: -0.01
# Kic: -0.01
# Loy: -0.01
# OtB: -0.01
# Spor: -0.02
# Ldr: -0.02
# Lon: -0.03
# L Th: -0.03
# 1v1: -0.03
# Fre: -0.04
# Cont: -0.04
# Mar: -0.05
# Pres: -0.06
# Fin: -0.09
# Com: -0.09
# Inj Pr: -0.09
# TRO: -0.09
# Ref: -0.10
# Cor: -0.11
# Aer: -0.13
# Ecc: -0.16
# Processing ball_winning_midfielder.csv...
# Top correlations in ball_winning_midfielder.csv:
# Pas: 0.36
# OtB: 0.36
# Ant: 0.35
# Tec: 0.34
# Cnt: 0.33
# Cro: 0.33
# Bal: 0.30
# Dri: 0.30
# Wor: 0.29
# Lon: 0.29
# Fir: 0.29
# Pos: 0.28
# Str: 0.28
# Hea: 0.27
# Cor: 0.27
# Tea: 0.27
# Sta: 0.27
# Bra: 0.27
# Vis: 0.26
# Fin: 0.26
# Fre: 0.25
# Mar: 0.25
# Tck: 0.24
# Cons: 0.24
# Cmp: 0.22
# Fla: 0.21
# Pac: 0.18
# L Th: 0.18
# Pen: 0.17
# Jum: 0.16
# Dec: 0.16
# Acc: 0.16
# Det: 0.16
# Thr: 0.14
# Agi: 0.12
# Pres: 0.11
# Ecc: 0.10
# Agg: 0.09
# Spor: 0.08
# Prof: 0.07
# Pun: 0.06
# Imp M: 0.06
# Amb: 0.05
# Inj Pr: 0.05
# Aer: 0.03
# Ref: 0.03
# Cont: 0.02
# Ldr: 0.01
# Dirt: 0.00
# Nat: -0.01
# Kic: -0.01
# Cmd: -0.03
# 1v1: -0.04
# Han: -0.04
# TRO: -0.05
# Com: -0.06
# Loy: -0.06
# Temp: -0.16
# Processing box_to_box_midfielder.csv...
# Top correlations in box_to_box_midfielder.csv:
# Cro: 0.23
# Lon: 0.20
# Bra: 0.20
# Pen: 0.20
# Cor: 0.20
# Fin: 0.19
# Hea: 0.18
# Bal: 0.18
# Ant: 0.17
# Fla: 0.17
# Dec: 0.16
# Cmp: 0.16
# Tea: 0.15
# Cons: 0.15
# Jum: 0.15
# Ldr: 0.15
# Prof: 0.15
# Cnt: 0.14
# Pas: 0.14
# Amb: 0.14
# Loy: 0.14
# Sta: 0.14
# Dri: 0.14
# Tec: 0.13
# OtB: 0.13
# Tck: 0.12
# Fre: 0.12
# Kic: 0.11
# Vis: 0.11
# Ecc: 0.11
# Wor: 0.11
# Fir: 0.10
# Agi: 0.10
# Pres: 0.09
# Pac: 0.09
# Agg: 0.09
# Acc: 0.08
# Spor: 0.08
# Str: 0.08
# Nat: 0.07
# L Th: 0.07
# Dirt: 0.05
# Temp: 0.04
# Mar: 0.04
# Det: 0.04
# 1v1: 0.03
# Inj Pr: 0.03
# Ref: 0.02
# Com: 0.02
# Pos: 0.02
# Imp M: 0.01
# Thr: -0.00
# Cont: -0.01
# Pun: -0.03
# Han: -0.07
# TRO: -0.07
# Aer: -0.11
# Cmd: -0.16
# Processing carrilero.csv...
# Top correlations in carrilero.csv:
# Sta: 0.36
# Wor: 0.29
# Pac: 0.24
# Imp M: 0.23
# Tck: 0.22
# Hea: 0.22
# Cro: 0.22
# Agi: 0.21
# Cnt: 0.21
# Str: 0.20
# Cons: 0.20
# Tec: 0.19
# Cor: 0.19
# Pos: 0.18
# Tea: 0.18
# Cmp: 0.17
# Pen: 0.17
# Fre: 0.16
# Kic: 0.16
# Bra: 0.15
# Ref: 0.15
# Bal: 0.14
# OtB: 0.14
# Vis: 0.13
# Dec: 0.13
# Mar: 0.13
# Acc: 0.12
# Ldr: 0.12
# Dri: 0.11
# Lon: 0.11
# Fir: 0.11
# Pas: 0.11
# Ant: 0.11
# Agg: 0.10
# L Th: 0.09
# Pres: 0.09
# Spor: 0.08
# Amb: 0.08
# Jum: 0.08
# Nat: 0.07
# Pun: 0.06
# Cont: 0.05
# Loy: 0.04
# 1v1: 0.03
# TRO: 0.02
# Fin: 0.02
# Temp: 0.01
# Det: 0.00
# Ecc: -0.00
# Cmd: -0.01
# Prof: -0.01
# Fla: -0.02
# Thr: -0.03
# Inj Pr: -0.05
# Dirt: -0.06
# Com: -0.07
# Han: -0.08
# Aer: -0.11
# Processing central_defender.csv...
# Top correlations in central_defender.csv:
# Hea: 0.33
# Bal: 0.33
# Str: 0.29
# Pac: 0.28
# Ant: 0.28
# Cmp: 0.25
# OtB: 0.25
# Cons: 0.24
# Agi: 0.23
# Cnt: 0.22
# Pas: 0.22
# Tea: 0.21
# Sta: 0.20
# Pos: 0.20
# Acc: 0.20
# Fir: 0.19
# Tck: 0.18
# Dri: 0.18
# Wor: 0.17
# Tec: 0.17
# Vis: 0.17
# Mar: 0.16
# Bra: 0.16
# Jum: 0.15
# Fin: 0.15
# Pen: 0.15
# Cor: 0.13
# Lon: 0.12
# Aer: 0.09
# Fre: 0.09
# Cro: 0.08
# Imp M: 0.06
# Inj Pr: 0.06
# Nat: 0.06
# L Th: 0.05
# Fla: 0.05
# Cmd: 0.04
# Cont: 0.04
# Amb: 0.04
# Ecc: 0.02
# Dec: 0.02
# Kic: 0.02
# Thr: 0.00
# Han: -0.00
# Dirt: -0.00
# Loy: -0.00
# Pres: -0.01
# Spor: -0.01
# Com: -0.01
# Pun: -0.01
# 1v1: -0.02
# Prof: -0.02
# TRO: -0.02
# Ref: -0.04
# Ldr: -0.05
# Det: -0.06
# Agg: -0.06
# Temp: -0.13
# Processing central_midfielder.csv...
# Top correlations in central_midfielder.csv:
# Acc: 0.32
# Pac: 0.28
# Bra: 0.28
# Agi: 0.26
# Cons: 0.24
# Cro: 0.22
# Cnt: 0.21
# Ant: 0.21
# Sta: 0.19
# Mar: 0.18
# Vis: 0.18
# Tea: 0.17
# Dec: 0.17
# OtB: 0.16
# Dri: 0.16
# Bal: 0.15
# Cor: 0.14
# Tec: 0.14
# L Th: 0.13
# Imp M: 0.13
# Str: 0.13
# Pas: 0.13
# Fre: 0.13
# Wor: 0.12
# Fla: 0.12
# TRO: 0.11
# Cmd: 0.11
# 1v1: 0.11
# Hea: 0.10
# Det: 0.10
# Cmp: 0.09
# Inj Pr: 0.08
# Pos: 0.07
# Prof: 0.07
# Fir: 0.07
# Han: 0.07
# Nat: 0.07
# Tck: 0.06
# Lon: 0.06
# Fin: 0.05
# Spor: 0.04
# Loy: 0.04
# Agg: 0.04
# Ldr: 0.04
# Amb: 0.02
# Pen: 0.01
# Jum: 0.01
# Ref: -0.00
# Pres: -0.03
# Aer: -0.03
# Com: -0.04
# Pun: -0.04
# Cont: -0.04
# Temp: -0.04
# Kic: -0.04
# Dirt: -0.05
# Thr: -0.07
# Ecc: -0.14
# Processing complete_forward.csv...
# Top correlations in complete_forward.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing complete_wing-back.csv...
# Top correlations in complete_wing-back.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing deep_lying_forward.csv...
# Top correlations in deep_lying_forward.csv:
# Pac: 0.36
# Sta: 0.34
# Fin: 0.29
# Bal: 0.28
# Str: 0.28
# Acc: 0.28
# Dri: 0.27
# Agi: 0.26
# Cmp: 0.24
# Wor: 0.23
# Hea: 0.22
# Tea: 0.22
# Dec: 0.22
# Ant: 0.21
# Pres: 0.20
# Cons: 0.20
# Cnt: 0.20
# Prof: 0.19
# Imp M: 0.19
# Tec: 0.18
# OtB: 0.18
# Jum: 0.17
# Pas: 0.17
# Nat: 0.16
# Det: 0.15
# Pen: 0.15
# Fla: 0.14
# Loy: 0.14
# Bra: 0.13
# Amb: 0.12
# Vis: 0.12
# Lon: 0.11
# Thr: 0.10
# Tck: 0.10
# L Th: 0.10
# Mar: 0.09
# Com: 0.09
# Temp: 0.09
# Aer: 0.08
# Fir: 0.07
# Agg: 0.04
# Ecc: 0.04
# Cont: 0.04
# Spor: 0.04
# Kic: 0.04
# Pos: 0.04
# Han: 0.03
# Ref: 0.02
# Pun: -0.01
# Ldr: -0.03
# Dirt: -0.03
# Fre: -0.04
# Cro: -0.06
# 1v1: -0.07
# Cmd: -0.07
# TRO: -0.09
# Cor: -0.12
# Inj Pr: -0.17
# Processing deep_lying_playmaker.csv...
# Top correlations in deep_lying_playmaker.csv:
# Sta: 0.32
# Agi: 0.30
# Pas: 0.29
# Ant: 0.28
# Pac: 0.27
# Tea: 0.27
# Dri: 0.26
# Cnt: 0.25
# Acc: 0.25
# Str: 0.24
# Wor: 0.23
# Pos: 0.21
# Hea: 0.21
# Bal: 0.20
# Tck: 0.20
# Tec: 0.20
# Fre: 0.20
# Cro: 0.20
# OtB: 0.20
# Vis: 0.19
# Fir: 0.18
# Dec: 0.18
# Pen: 0.16
# Cons: 0.15
# Lon: 0.14
# Cor: 0.14
# Mar: 0.14
# L Th: 0.13
# Jum: 0.13
# Imp M: 0.13
# Pres: 0.13
# Cmp: 0.12
# Han: 0.12
# Bra: 0.10
# Det: 0.10
# Amb: 0.10
# Nat: 0.08
# Fin: 0.08
# Aer: 0.06
# Ref: 0.06
# Cmd: 0.05
# Fla: 0.05
# Spor: 0.04
# Dirt: 0.03
# Ecc: 0.03
# Com: 0.02
# Prof: 0.02
# Pun: 0.02
# TRO: 0.01
# Loy: 0.01
# Cont: -0.01
# Thr: -0.01
# Temp: -0.02
# Ldr: -0.03
# Kic: -0.03
# Inj Pr: -0.03
# Agg: -0.03
# 1v1: -0.04
# Processing defensive_midfielder.csv...
# Top correlations in defensive_midfielder.csv:
# Bal: 0.47
# Str: 0.44
# Cnt: 0.43
# Bra: 0.43
# Ant: 0.43
# Pos: 0.41
# Tea: 0.41
# Hea: 0.40
# Dri: 0.40
# Cmp: 0.39
# Pen: 0.38
# Pas: 0.38
# Sta: 0.37
# Cro: 0.37
# Mar: 0.37
# Tec: 0.36
# OtB: 0.36
# Pac: 0.34
# Fir: 0.34
# Fre: 0.34
# Cor: 0.34
# L Th: 0.32
# Fin: 0.32
# Jum: 0.32
# Vis: 0.31
# Lon: 0.30
# Wor: 0.27
# Fla: 0.27
# Tck: 0.26
# Imp M: 0.26
# Cons: 0.25
# Agi: 0.25
# Acc: 0.23
# Ldr: 0.18
# Det: 0.17
# Dec: 0.15
# Amb: 0.13
# Thr: 0.13
# Loy: 0.11
# Prof: 0.10
# Spor: 0.05
# Kic: 0.05
# Nat: 0.04
# Temp: 0.04
# Pres: 0.03
# Cont: 0.02
# 1v1: 0.02
# Agg: -0.00
# Ref: -0.01
# Com: -0.01
# Pun: -0.01
# Ecc: -0.01
# TRO: -0.04
# Cmd: -0.04
# Aer: -0.05
# Inj Pr: -0.06
# Han: -0.09
# Dirt: -0.12
# Processing defensive_winger.csv...
# Top correlations in defensive_winger.csv:
# Agi: 0.34
# Dri: 0.34
# Acc: 0.33
# Pac: 0.29
# Sta: 0.28
# Mar: 0.26
# Str: 0.26
# Cnt: 0.23
# Hea: 0.23
# Bal: 0.23
# Pos: 0.22
# Cmp: 0.22
# Vis: 0.22
# Cons: 0.21
# Ant: 0.21
# Tea: 0.19
# L Th: 0.19
# Bra: 0.19
# Tck: 0.19
# Cor: 0.19
# Lon: 0.18
# Pen: 0.17
# Pas: 0.17
# Fre: 0.15
# Tec: 0.13
# Kic: 0.13
# Cro: 0.13
# Wor: 0.12
# Dec: 0.10
# Fin: 0.08
# OtB: 0.08
# Prof: 0.06
# Loy: 0.05
# Fir: 0.04
# Pun: 0.02
# Imp M: 0.02
# Ref: 0.01
# Nat: 0.01
# Agg: 0.01
# Jum: 0.01
# TRO: -0.00
# Fla: -0.01
# 1v1: -0.01
# Pres: -0.02
# Han: -0.02
# Thr: -0.02
# Ecc: -0.03
# Amb: -0.05
# Det: -0.05
# Spor: -0.06
# Ldr: -0.06
# Dirt: -0.06
# Cmd: -0.07
# Cont: -0.07
# Com: -0.08
# Aer: -0.10
# Inj Pr: -0.12
# Temp: -0.16
# Processing enganche.csv...
# Top correlations in enganche.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing false_nine.csv...
# Top correlations in false_nine.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing full-back.csv...
# Top correlations in full-back.csv:
# Fin: 0.35
# Sta: 0.35
# Dri: 0.34
# Bal: 0.33
# OtB: 0.31
# Tec: 0.30
# Tea: 0.30
# Vis: 0.29
# Fir: 0.28
# Cor: 0.28
# Pac: 0.28
# Wor: 0.28
# Bra: 0.27
# Cro: 0.27
# Str: 0.27
# Cmp: 0.26
# Lon: 0.26
# Pas: 0.25
# Pen: 0.25
# Fre: 0.22
# Acc: 0.21
# Pos: 0.20
# L Th: 0.20
# Agi: 0.19
# Mar: 0.17
# Ant: 0.16
# Hea: 0.15
# Tck: 0.14
# Cons: 0.14
# Cnt: 0.14
# Fla: 0.12
# Loy: 0.12
# 1v1: 0.11
# Jum: 0.11
# Imp M: 0.11
# Han: 0.10
# Com: 0.08
# Thr: 0.07
# Temp: 0.06
# Prof: 0.04
# Cont: 0.03
# Aer: 0.02
# Kic: 0.02
# Det: 0.01
# Pun: 0.01
# Ldr: -0.01
# Cmd: -0.01
# Dec: -0.02
# Inj Pr: -0.03
# TRO: -0.06
# Nat: -0.08
# Pres: -0.08
# Amb: -0.09
# Agg: -0.09
# Ref: -0.10
# Ecc: -0.10
# Spor: -0.11
# Dirt: -0.19
# Processing goalkeeper.csv...
# Top correlations in goalkeeper.csv:
# Tck: nan
# Ref: 0.33
# Acc: 0.27
# Com: 0.24
# Pac: 0.21
# Cmd: 0.21
# Cons: 0.20
# Thr: 0.20
# Ant: 0.20
# Ecc: 0.19
# Pas: 0.18
# Bal: 0.18
# Pos: 0.18
# Str: 0.18
# Aer: 0.18
# Agi: 0.17
# Vis: 0.17
# Han: 0.16
# 1v1: 0.16
# Cmp: 0.15
# Kic: 0.15
# Tea: 0.15
# Wor: 0.15
# Agg: 0.14
# Cnt: 0.13
# Nat: 0.13
# Fre: 0.12
# Cor: 0.12
# Fir: 0.11
# Sta: 0.10
# Dri: 0.10
# Tec: 0.10
# Bra: 0.08
# Imp M: 0.08
# Dec: 0.07
# Spor: 0.07
# Cont: 0.06
# Pun: 0.06
# Amb: 0.05
# Jum: 0.04
# Inj Pr: 0.04
# Fla: 0.03
# Cro: 0.03
# Pres: 0.02
# Pen: 0.02
# TRO: 0.02
# Mar: 0.01
# Temp: 0.01
# Hea: 0.00
# Det: -0.00
# Loy: -0.01
# L Th: -0.02
# OtB: -0.03
# Fin: -0.04
# Ldr: -0.04
# Dirt: -0.04
# Lon: -0.10
# Prof: -0.10
# Processing half_back.csv...
# Top correlations in half_back.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing inside_forward.csv...
# Top correlations in inside_forward.csv:
# Dri: 0.33
# Dec: 0.32
# Ant: 0.32
# Acc: 0.31
# Cons: 0.30
# Cnt: 0.30
# Fin: 0.30
# OtB: 0.30
# Cor: 0.29
# Pac: 0.28
# Sta: 0.27
# Bra: 0.27
# Cmp: 0.27
# Tec: 0.26
# Str: 0.26
# Hea: 0.26
# Wor: 0.25
# Cro: 0.25
# Lon: 0.24
# Fre: 0.23
# Vis: 0.23
# Pos: 0.22
# Fla: 0.22
# Prof: 0.21
# Pas: 0.21
# Tea: 0.20
# Imp M: 0.20
# Agi: 0.19
# Nat: 0.19
# Mar: 0.18
# Fir: 0.18
# Pres: 0.17
# Det: 0.17
# Bal: 0.16
# Jum: 0.14
# Pen: 0.14
# Tck: 0.14
# Amb: 0.13
# L Th: 0.13
# Loy: 0.11
# Agg: 0.11
# Cmd: 0.10
# Han: 0.08
# Spor: 0.08
# Thr: 0.07
# Cont: 0.06
# Dirt: 0.01
# Kic: 0.01
# Ldr: 0.00
# Ref: -0.00
# Inj Pr: -0.00
# Aer: -0.01
# 1v1: -0.01
# Pun: -0.07
# Temp: -0.07
# TRO: -0.07
# Com: -0.12
# Ecc: -0.15
# Processing inverted_wing-back.csv...
# Top correlations in inverted_wing-back.csv:
# Bal: 0.42
# Str: 0.40
# Bra: 0.39
# Ant: 0.38
# Cmp: 0.38
# Pos: 0.37
# OtB: 0.36
# Mar: 0.35
# Tec: 0.35
# Tck: 0.35
# Pas: 0.34
# Cons: 0.34
# Cro: 0.32
# Fla: 0.32
# Tea: 0.31
# Wor: 0.31
# Lon: 0.29
# L Th: 0.29
# Sta: 0.28
# Fir: 0.28
# Hea: 0.27
# Cnt: 0.27
# Pen: 0.26
# Fre: 0.26
# Dri: 0.26
# Cor: 0.25
# Agi: 0.24
# Vis: 0.24
# Pac: 0.21
# Acc: 0.21
# Prof: 0.17
# Jum: 0.15
# Imp M: 0.15
# Dec: 0.13
# Kic: 0.13
# Fin: 0.12
# Ldr: 0.12
# Agg: 0.11
# 1v1: 0.11
# Pun: 0.08
# Ecc: 0.08
# Ref: 0.06
# Han: 0.04
# Cmd: 0.04
# Det: 0.02
# TRO: 0.01
# Dirt: 0.00
# Pres: -0.00
# Cont: -0.01
# Loy: -0.03
# Com: -0.03
# Amb: -0.07
# Temp: -0.08
# Aer: -0.08
# Spor: -0.08
# Thr: -0.08
# Nat: -0.09
# Inj Pr: -0.14
# Processing inverted_winger.csv...
# Top correlations in inverted_winger.csv:
# Bal: 0.30
# Ant: 0.30
# Pas: 0.30
# Agi: 0.29
# Cor: 0.28
# Cro: 0.28
# Cnt: 0.27
# Str: 0.27
# Lon: 0.27
# Fre: 0.27
# Cmp: 0.25
# Sta: 0.25
# Pen: 0.25
# Acc: 0.25
# OtB: 0.25
# Vis: 0.24
# Fla: 0.24
# Pos: 0.23
# Cons: 0.23
# Tec: 0.23
# Fin: 0.23
# Dec: 0.23
# Tea: 0.23
# Dri: 0.22
# Pac: 0.21
# Wor: 0.21
# Bra: 0.20
# Fir: 0.20
# L Th: 0.17
# Imp M: 0.16
# Mar: 0.16
# Com: 0.14
# Hea: 0.11
# Jum: 0.10
# Spor: 0.10
# Tck: 0.09
# Det: 0.08
# Aer: 0.08
# Amb: 0.07
# Pun: 0.04
# Nat: 0.03
# Prof: 0.03
# TRO: 0.02
# Cont: 0.02
# Inj Pr: 0.01
# Han: 0.01
# Ldr: 0.00
# Kic: -0.00
# Loy: -0.00
# Thr: -0.03
# Ref: -0.03
# Pres: -0.03
# Ecc: -0.04
# 1v1: -0.04
# Temp: -0.04
# Cmd: -0.05
# Agg: -0.09
# Dirt: -0.11
# Processing libero.csv...
# Top correlations in libero.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing mezzala.csv...
# Top correlations in mezzala.csv:
# e:\Python\anaconda3\envs\project_fm\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# e:\Python\anaconda3\envs\project_fm\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# e:\Python\anaconda3\envs\project_fm\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# e:\Python\anaconda3\envs\project_fm\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Cons: 0.37
# Str: 0.30
# Bal: 0.29
# Cor: 0.29
# OtB: 0.28
# Cnt: 0.26
# Cro: 0.25
# Fin: 0.25
# Fre: 0.25
# Cmp: 0.25
# Dri: 0.24
# Lon: 0.24
# Pas: 0.24
# Vis: 0.23
# Ant: 0.22
# Tec: 0.22
# Pen: 0.22
# Imp M: 0.21
# Pos: 0.20
# Tck: 0.20
# Sta: 0.20
# Tea: 0.19
# Fla: 0.17
# Bra: 0.17
# L Th: 0.17
# Hea: 0.16
# Mar: 0.16
# Agi: 0.16
# Wor: 0.15
# Fir: 0.14
# Dec: 0.13
# Pac: 0.11
# Acc: 0.10
# Ldr: 0.07
# Pres: 0.06
# Ref: 0.06
# Spor: 0.06
# Cmd: 0.06
# Jum: 0.05
# Prof: 0.05
# Cont: 0.04
# 1v1: 0.03
# Ecc: 0.02
# Com: 0.01
# Det: 0.01
# Nat: 0.00
# Thr: 0.00
# Temp: -0.00
# Dirt: -0.01
# Aer: -0.01
# TRO: -0.03
# Agg: -0.04
# Pun: -0.04
# Kic: -0.04
# Amb: -0.05
# Loy: -0.05
# Inj Pr: -0.08
# Han: -0.09
# Processing no-nonsense_centre-back.csv...
# Top correlations in no-nonsense_centre-back.csv:
# Pas: 0.39
# Str: 0.38
# Vis: 0.37
# Fir: 0.37
# Tec: 0.37
# Dri: 0.36
# Sta: 0.36
# Ant: 0.36
# Bal: 0.36
# Tck: 0.34
# Wor: 0.34
# Lon: 0.34
# Cnt: 0.34
# OtB: 0.33
# Cmp: 0.33
# L Th: 0.33
# Hea: 0.33
# Tea: 0.32
# Pen: 0.31
# Fre: 0.31
# Fin: 0.30
# Cons: 0.27
# Bra: 0.27
# Cro: 0.25
# Pac: 0.25
# Cor: 0.24
# Agi: 0.24
# Jum: 0.22
# Acc: 0.22
# Mar: 0.21
# Dec: 0.16
# Pos: 0.16
# Det: 0.14
# Fla: 0.14
# Amb: 0.13
# Nat: 0.12
# Kic: 0.11
# Ecc: 0.08
# Com: 0.07
# Agg: 0.07
# Cont: 0.07
# Ldr: 0.06
# Han: 0.06
# Prof: 0.05
# Ref: 0.05
# Imp M: 0.02
# Loy: 0.01
# Cmd: -0.00
# TRO: -0.01
# Spor: -0.02
# Pun: -0.02
# 1v1: -0.04
# Pres: -0.05
# Aer: -0.07
# Dirt: -0.07
# Temp: -0.08
# Thr: -0.08
# Inj Pr: -0.21
# Processing no-nonsense_full-back.csv...
# Top correlations in no-nonsense_full-back.csv:
# OtB: 0.33
# Bal: 0.33
# Cnt: 0.33
# Hea: 0.32
# Vis: 0.31
# Dri: 0.31
# Ant: 0.29
# Pac: 0.29
# Str: 0.28
# Tea: 0.27
# Pas: 0.26
# Fir: 0.26
# Sta: 0.26
# L Th: 0.26
# Wor: 0.25
# Fin: 0.25
# Pos: 0.24
# Cmp: 0.24
# Tec: 0.24
# Acc: 0.23
# Lon: 0.23
# Cons: 0.22
# Bra: 0.22
# Cro: 0.21
# Cor: 0.20
# Agi: 0.19
# Pen: 0.19
# Tck: 0.18
# Fla: 0.17
# Fre: 0.17
# Mar: 0.12
# Jum: 0.10
# Imp M: 0.10
# Kic: 0.09
# Com: 0.09
# Dirt: 0.07
# Inj Pr: 0.06
# Cont: 0.06
# Ldr: 0.05
# Dec: 0.04
# Aer: 0.04
# Amb: 0.04
# Ecc: 0.04
# Temp: 0.03
# Agg: 0.02
# Ref: -0.00
# 1v1: -0.04
# Pun: -0.04
# Nat: -0.04
# Han: -0.04
# Cmd: -0.05
# TRO: -0.06
# Det: -0.07
# Loy: -0.07
# Spor: -0.10
# Pres: -0.11
# Thr: -0.11
# Prof: -0.15
# Processing poacher.csv...
# Top correlations in poacher.csv:
# Tea: 0.34
# Tck: nan
# Dri: 0.40
# Wor: 0.35
# Mar: 0.33
# Pos: 0.30
# Vis: 0.30
# Acc: 0.30
# Cnt: 0.29
# Cons: 0.29
# Tec: 0.28
# Sta: 0.27
# Cor: 0.27
# Pas: 0.27
# Agi: 0.26
# Dec: 0.24
# Cmp: 0.24
# Pac: 0.24
# Bra: 0.23
# OtB: 0.23
# Fre: 0.23
# Ant: 0.23
# Bal: 0.22
# Pen: 0.22
# Cro: 0.21
# Fin: 0.21
# Lon: 0.21
# Str: 0.20
# Fir: 0.19
# L Th: 0.18
# Hea: 0.17
# Fla: 0.13
# Thr: 0.12
# Han: 0.10
# 1v1: 0.09
# Ldr: 0.09
# Inj Pr: 0.08
# Com: 0.08
# Spor: 0.06
# Imp M: 0.05
# Agg: 0.05
# Aer: 0.04
# TRO: 0.02
# Ref: 0.02
# Jum: 0.02
# Cmd: 0.02
# Det: 0.00
# Prof: 0.00
# Kic: -0.01
# Nat: -0.01
# Cont: -0.03
# Pun: -0.04
# Pres: -0.06
# Amb: -0.06
# Loy: -0.08
# Dirt: -0.10
# Temp: -0.10
# Ecc: -0.11
# Processing pressing_forward.csv...
# Top correlations in pressing_forward.csv:
# Pen: 0.47
# Cmp: 0.44
# Tec: 0.41
# Bal: 0.40
# Vis: 0.40
# Tea: 0.40
# Pas: 0.39
# Cnt: 0.38
# Dri: 0.37
# Lon: 0.37
# Wor: 0.37
# Bra: 0.36
# Hea: 0.36
# Str: 0.36
# Sta: 0.36
# Ant: 0.35
# Fin: 0.35
# OtB: 0.35
# Cro: 0.33
# Jum: 0.33
# Dec: 0.31
# Fre: 0.30
# Fir: 0.29
# Fla: 0.29
# Mar: 0.27
# Cor: 0.26
# Tck: 0.26
# L Th: 0.25
# Pos: 0.24
# Det: 0.23
# Imp M: 0.23
# Acc: 0.19
# Agi: 0.17
# Cons: 0.17
# Cont: 0.17
# Agg: 0.15
# Pac: 0.14
# Prof: 0.09
# TRO: 0.06
# Nat: 0.06
# Amb: 0.06
# Pres: 0.05
# Kic: 0.03
# Ldr: 0.02
# Ecc: 0.01
# Pun: -0.01
# Loy: -0.02
# Spor: -0.02
# Com: -0.02
# 1v1: -0.03
# Thr: -0.04
# Aer: -0.05
# Cmd: -0.05
# Dirt: -0.06
# Ref: -0.09
# Han: -0.09
# Inj Pr: -0.10
# Temp: -0.12
# Processing raumdeuter.csv...
# Top correlations in raumdeuter.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing regista.csv...
# Top correlations in regista.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing roaming_playmaker.csv...
# Top correlations in roaming_playmaker.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing segundo_volante.csv...
# Top correlations in segundo_volante.csv:
# Ant: 0.22
# Str: 0.20
# Tea: 0.19
# Hea: 0.17
# Imp M: 0.17
# Cmp: 0.17
# Pas: 0.17
# Bra: 0.16
# Pos: 0.16
# Dri: 0.15
# OtB: 0.15
# Det: 0.14
# Fre: 0.14
# Pen: 0.13
# Lon: 0.12
# Cmd: 0.12
# Cor: 0.11
# Cro: 0.11
# Ecc: 0.10
# Bal: 0.10
# Cons: 0.10
# Dec: 0.10
# Fin: 0.09
# Fla: 0.09
# Pres: 0.09
# Ref: 0.09
# Wor: 0.09
# Kic: 0.09
# Mar: 0.08
# Jum: 0.07
# Cnt: 0.06
# Agg: 0.03
# Vis: 0.03
# Agi: 0.03
# Aer: 0.02
# Loy: 0.01
# 1v1: 0.01
# Fir: -0.00
# Pun: -0.01
# L Th: -0.01
# Tec: -0.01
# Pac: -0.02
# Thr: -0.02
# Nat: -0.02
# TRO: -0.05
# Tck: -0.05
# Han: -0.05
# Temp: -0.07
# Prof: -0.07
# Spor: -0.08
# Sta: -0.10
# Amb: -0.10
# Acc: -0.11
# Ldr: -0.11
# Com: -0.11
# Dirt: -0.13
# Inj Pr: -0.16
# Cont: -0.19
# Processing shadow_striker.csv...
# Top correlations in shadow_striker.csv:
# Mar: 0.35
# Cons: 0.31
# Fin: 0.30
# Hea: 0.29
# Vis: 0.29
# Tea: 0.27
# Pas: 0.27
# Fre: 0.27
# OtB: 0.26
# Cnt: 0.26
# Ant: 0.25
# Pos: 0.25
# Bal: 0.24
# L Th: 0.22
# Cor: 0.22
# Dri: 0.22
# Cro: 0.21
# Tck: 0.21
# Jum: 0.20
# Lon: 0.20
# Str: 0.20
# Tec: 0.20
# Wor: 0.19
# Bra: 0.19
# Pen: 0.19
# TRO: 0.18
# Imp M: 0.18
# Fla: 0.16
# Acc: 0.16
# Agi: 0.15
# Pac: 0.15
# Sta: 0.13
# Ldr: 0.13
# Ecc: 0.11
# Cmd: 0.10
# Cont: 0.10
# Nat: 0.10
# Det: 0.10
# Kic: 0.09
# Agg: 0.09
# Cmp: 0.08
# Amb: 0.08
# Com: 0.08
# Dec: 0.07
# Spor: 0.06
# Prof: 0.06
# Thr: 0.04
# Dirt: 0.04
# Fir: 0.03
# Aer: 0.03
# Loy: 0.03
# Temp: 0.00
# Pres: -0.02
# Ref: -0.02
# 1v1: -0.06
# Pun: -0.06
# Inj Pr: -0.11
# Han: -0.12
# Processing sweeper_keeper.csv...
# Top correlations in sweeper_keeper.csv:
# Thr: 0.22
# Tck: nan
# Ant: 0.23
# Cmd: 0.21
# Bal: 0.20
# Cmp: 0.20
# Vis: 0.20
# Tea: 0.19
# Cons: 0.17
# 1v1: 0.16
# Fre: 0.16
# Com: 0.16
# Wor: 0.16
# Inj Pr: 0.15
# Cnt: 0.15
# Ref: 0.15
# Pas: 0.15
# Kic: 0.15
# Fir: 0.15
# Str: 0.14
# Pac: 0.14
# Bra: 0.13
# Sta: 0.12
# Han: 0.12
# Tec: 0.12
# Hea: 0.12
# Aer: 0.12
# Acc: 0.12
# Jum: 0.11
# Pos: 0.11
# Cor: 0.11
# Amb: 0.09
# Lon: 0.09
# Det: 0.09
# Dec: 0.08
# Pen: 0.08
# Agi: 0.08
# Pun: 0.08
# Ldr: 0.07
# Fin: 0.06
# Cont: 0.06
# Fla: 0.05
# L Th: 0.04
# Imp M: 0.03
# Agg: 0.02
# Mar: 0.01
# Ecc: 0.00
# OtB: -0.00
# TRO: -0.01
# Cro: -0.01
# Dirt: -0.01
# Dri: -0.01
# Spor: -0.02
# Loy: -0.02
# Pres: -0.02
# Prof: -0.03
# Nat: -0.03
# Temp: -0.14
# Processing target_forward.csv...
# Top correlations in target_forward.csv:
# Pac: 0.30
# Dri: 0.27
# Acc: 0.25
# Sta: 0.24
# Agi: 0.24
# OtB: 0.24
# Fin: 0.23
# Cnt: 0.22
# Str: 0.22
# Hea: 0.20
# Cmp: 0.20
# Fir: 0.19
# Nat: 0.18
# Wor: 0.17
# Pos: 0.17
# Pres: 0.17
# Dec: 0.17
# Vis: 0.15
# TRO: 0.13
# Prof: 0.12
# Ant: 0.11
# Jum: 0.11
# Tea: 0.11
# Tck: 0.10
# Mar: 0.10
# Pas: 0.10
# Cons: 0.09
# Lon: 0.08
# Tec: 0.08
# Spor: 0.08
# Bra: 0.07
# Ref: 0.06
# Cro: 0.06
# Det: 0.06
# Fla: 0.05
# Fre: 0.05
# Cor: 0.05
# Bal: 0.04
# Thr: 0.04
# Amb: 0.04
# Pen: 0.04
# Ecc: 0.04
# Kic: 0.02
# Aer: 0.02
# Agg: 0.01
# L Th: 0.01
# Ldr: 0.01
# Imp M: 0.01
# 1v1: 0.01
# Han: 0.00
# Loy: 0.00
# Cont: -0.02
# Pun: -0.03
# Cmd: -0.03
# Temp: -0.04
# Com: -0.07
# Dirt: -0.09
# Inj Pr: -0.10
# Processing trequartista.csv...
# Top correlations in trequartista.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing wide_centre_back.csv...
# Top correlations in wide_centre_back.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing wide_midfielder.csv...
# Top correlations in wide_midfielder.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing wide_playmaker.csv...
# Top correlations in wide_playmaker.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing wide_target_forward.csv...
# Top correlations in wide_target_forward.csv:
# Not enough data for a statistically safe calculation. At least 30 rows are recommended.
# Processing wing-back.csv...
# Top correlations in wing-back.csv:
# Tck: 0.34
# Bra: 0.33
# Bal: 0.33
# Cmp: 0.32
# Pas: 0.31
# Dri: 0.31
# Mar: 0.30
# Str: 0.29
# Vis: 0.28
# Fre: 0.28
# Hea: 0.28
# OtB: 0.27
# Tec: 0.27
# Tea: 0.26
# Wor: 0.26
# Ant: 0.26
# Fin: 0.26
# Fla: 0.25
# L Th: 0.25
# Lon: 0.25
# Pos: 0.25
# Sta: 0.24
# Cor: 0.23
# Cons: 0.23
# Fir: 0.23
# Pac: 0.22
# Pen: 0.21
# Jum: 0.20
# Cnt: 0.19
# Cro: 0.19
# Imp M: 0.14
# Acc: 0.14
# Agi: 0.13
# Com: 0.13
# Nat: 0.10
# Det: 0.10
# Dec: 0.09
# Han: 0.09
# Agg: 0.09
# Ecc: 0.05
# Amb: 0.04
# TRO: 0.03
# Pres: 0.00
# Ref: -0.01
# Pun: -0.01
# Thr: -0.01
# 1v1: -0.02
# Aer: -0.02
# Prof: -0.02
# Ldr: -0.02
# Cont: -0.04
# Inj Pr: -0.04
# Cmd: -0.04
# Loy: -0.06
# Kic: -0.07
# Dirt: -0.08
# Temp: -0.09
# Spor: -0.12
# Processing winger.csv...
# Top correlations in winger.csv:
# Cmp: 0.33
# Pos: 0.29
# Mar: 0.29
# Ant: 0.29
# Pac: 0.27
# Cons: 0.26
# Cro: 0.25
# Acc: 0.25
# Cnt: 0.24
# Pas: 0.24
# Fin: 0.23
# OtB: 0.23
# Tea: 0.22
# L Th: 0.21
# Hea: 0.21
# Agi: 0.20
# Cor: 0.19
# Pen: 0.19
# Vis: 0.19
# Fir: 0.18
# Dri: 0.17
# Bra: 0.17
# Wor: 0.15
# Amb: 0.15
# Str: 0.15
# Dec: 0.15
# Lon: 0.13
# Fla: 0.13
# Sta: 0.12
# Temp: 0.11
# Tec: 0.11
# Fre: 0.10
# Imp M: 0.10
# Pun: 0.09
# Bal: 0.09
# Ref: 0.08
# Jum: 0.06
# Kic: 0.06
# Pres: 0.04
# 1v1: 0.04
# Tck: 0.03
# Thr: 0.03
# Ldr: 0.02
# Han: 0.01
# Prof: -0.00
# Det: -0.02
# Dirt: -0.03
# Loy: -0.03
# Com: -0.03
# Cmd: -0.03
# Aer: -0.04
# Inj Pr: -0.05
# TRO: -0.05
# Ecc: -0.06
# Spor: -0.06
# Agg: -0.08
# Nat: -0.10
# Cont: -0.13
# e:\Python\anaconda3\envs\project_fm\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# e:\Python\anaconda3\envs\project_fm\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
# import numpy as np
# from scipy.stats import pearsonr
# from sklearn.feature_selection import RFE
# from sklearn.linear_model import LinearRegression

# def calculate_predictive_attributes(df, threshold=0.2):
#     # Ensure 'Av Rat' column exists and clean the data
#     if 'Av Rat' not in df.columns:
#         raise ValueError("'Av Rat' column is not present in the DataFrame")

#     df_copy = df.copy()
#     df_copy['Av Rat'] = df_copy['Av Rat'].str.strip()
#     df_copy['Av Rat'] = pd.to_numeric(df_copy['Av Rat'], errors='coerce')
#     df_copy = df_copy.dropna(subset=['Av Rat'])

#     # Debug: Check the data after cleaning
#     print("Data after cleaning and converting 'Av Rat':")
#     print(df_copy.head())

#     # # Remove the bottom 5% and upper 5% outliers from 'Av Rat'
#     # lower_bound = df_copy['Av Rat'].quantile(0.05)
#     # upper_bound = df_copy['Av Rat'].quantile(0.95)
#     # df_copy = df_copy[(df_copy['Av Rat'] >= lower_bound) & (df_copy['Av Rat'] <= upper_bound)]

#     # # Debug: Check the data after removing outliers
#     # print(f"\nData after removing outliers (5th and 95th percentiles): {lower_bound}, {upper_bound}")
#     # print(df_copy.head())

#     # Select numeric columns representing player attributes
#     attributes = df_copy.select_dtypes(include=['int64', 'float64']).columns.drop('Av Rat')

#     # Debug: Check the selected attribute columns
#     print(f"\nSelected attributes: {list(attributes)}")

#     # Calculate correlations with 'Av Rat' and filter based on the threshold
#     correlations = df_copy[attributes].apply(lambda x: pearsonr(x, df_copy['Av Rat'])[0])
#     significant_correlations = correlations[abs(correlations) > threshold]

#     # Debug: Check the significant correlations
#     print(f"\nSignificant correlations (threshold={threshold}):")
#     print(significant_correlations)

#     # Check if there are any significant correlations
#     if significant_correlations.empty:
#         print("\nNo significant correlations found above the threshold.")
#         return pd.Series(dtype=float)  # Return an empty Series

#     # Feature selection using RFE
#     X = df_copy[significant_correlations.index]
#     y = df_copy['Av Rat']

#     # Debug: Check the data being passed to RFE
#     print(f"\nData passed to RFE (features):")
#     print(X.head())
#     print(f"\nData passed to RFE (target):")
#     print(y.head())

#     model = LinearRegression()
#     n_features_to_select = min(5, len(significant_correlations))
#     rfe = RFE(model, n_features_to_select=n_features_to_select)
#     fit = rfe.fit(X, y)

#     # Filter features selected by RFE
#     rfe_selected = X.columns[fit.support_]
#     final_correlations = significant_correlations[rfe_selected]

#     return final_correlations

# # Example usage
# # Assuming df is already defined and loaded with the necessary data
# correlations = calculate_predictive_attributes(df).sort_values(ascending=False)
# print("\nFinal significant correlations:")
# print(correlations)

# %%
# Create a function that given a folder will perform correlations on all csvs and then merge thwm
# Out:
# <class 'pandas.core.series.Series'>
# Index: 47 entries, Bra to Nat
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 47 non-null     float64
# dtypes: float64(1)
# memory usage: 752.0+ bytes

# %%
import os

def process_csv_files(folder_path):
    # List to hold results
    results = []

    # Iterate through all CSV files in the specified folder
    for filename in os.listdir(folder_path):
        if filename.endswith('.csv'):
            file_path = os.path.join(folder_path, filename)
            print(f"Processing file: {file_path}")

            try:
                # Load the CSV file into a DataFrame
                df = pd.read_csv(file_path)

                # Check if 'Av Rat' column exists
                if 'Av Rat' not in df.columns:
                    print(f"'Av Rat' column not found in {filename}")
                    continue

                # Create a copy of the DataFrame to avoid modifying the original
                df_copy = df.copy()

                # Clean and convert 'Av Rat' column to float
                df_copy['Av Rat'] = df_copy['Av Rat'].str.strip()  # Remove any leading/trailing whitespace
                df_copy['Av Rat'] = pd.to_numeric(df_copy['Av Rat'], errors='coerce')  # Convert to numeric, set invalid parsing as NaN

                # Drop rows where 'Av Rat' could not be converted (if any)
                df_copy = df_copy.dropna(subset=['Av Rat'])

                # Calculate the average of 'Av Rat'
                avg_av_rat = df_copy['Av Rat'].mean()

                # Append the result to the list
                results.append({'File Name': filename, 'Average Av Rat': avg_av_rat})

            except Exception as e:
                print(f"Error processing file {filename}: {e}")

    # Create a DataFrame from the results
    results_df = pd.DataFrame(results)

    return results_df

# Example usage
folder_path = 'data/merged/csv/'  # Replace with your folder path
results_df = process_csv_files(folder_path).sort_values(by='Average Av Rat', ascending=False)
print(results_df)

# # Optionally, save the results to a CSV file
# results_df.to_csv('average_av_rat_results.csv', index=False)
# Out:
# Processing file: data/merged/csv/amcconfdiv2.csv
# Processing file: data/merged/csv/amlrconfdiv2.csv
# Processing file: data/merged/csv/dcconfdiv2.csv
# Processing file: data/merged/csv/dmconfdiv2.csv
# Processing file: data/merged/csv/fbconfdiv2.csv
# Processing file: data/merged/csv/gkconfdiv2.csv
# Processing file: data/merged/csv/mcconfdiv2.csv
# Processing file: data/merged/csv/mlrconfdiv2.csv
# Processing file: data/merged/csv/scconfdiv2.csv
# Processing file: data/merged/csv/wbconfdiv2.csv
#           File Name  Average Av Rat
# 7   mlrconfdiv2.csv        6.828176
# 1  amlrconfdiv2.csv        6.825186
# 0   amcconfdiv2.csv        6.789392
# 4    fbconfdiv2.csv        6.769615
# 9    wbconfdiv2.csv        6.768086
# 8    scconfdiv2.csv        6.767237
# 6    mcconfdiv2.csv        6.753380
# 2    dcconfdiv2.csv        6.744420
# 3    dmconfdiv2.csv        6.727583
# 5    gkconfdiv2.csv        6.566448

# %% [markdown]
# Now I know that dm and wb tend to perform subpar in conference and division 2. On the other hand wingers of any kind and attacking midfielders perform better.

# %% [markdown]
# The following code will take all csvs from all the years and basically turn them into a new one located at 'data/merged/csv/'

# %%
import pandas as pd
import os
from pathlib import Path

def merge_csv_files(src_folder, dest_folder):
    # Ensure the destination folder exists
    os.makedirs(dest_folder, exist_ok=True)

    # Dictionary to hold DataFrames for merging
    dataframes = {}

    # Walk through all subdirectories starting with 'year'
    for root, dirs, files in os.walk(src_folder):
        for dir_name in dirs:
            if dir_name.startswith('year'):
                year_folder = os.path.join(root, dir_name)
                csv_folder = os.path.join(year_folder, 'csv')

                if not os.path.exists(csv_folder):
                    print(f"No 'csv' folder found in {year_folder}")
                    continue

                # Process each CSV file in the 'csv' folder
                for file_name in os.listdir(csv_folder):
                    if file_name.endswith('.csv'):
                        file_path = os.path.join(csv_folder, file_name)

                        # Read CSV file
                        df = pd.read_csv(file_path)

                        # Use the file name (without extension) as the key
                        base_name = os.path.splitext(file_name)[0]

                        if base_name in dataframes:
                            # Append data to existing DataFrame
                            dataframes[base_name] = pd.concat([dataframes[base_name], df], ignore_index=True)
                        else:
                            # Create a new DataFrame entry
                            dataframes[base_name] = df

    # Save all merged DataFrames to the destination folder
    for base_name, df in dataframes.items():
        output_path = os.path.join(dest_folder, f"{base_name}.csv")
        df.to_csv(output_path, index=False)
        print(f"Saved merged file: {output_path}")

# Define source and destination folders
source_folder = 'data'
destination_folder = 'data/merged/csv'

# Merge CSV files
merge_csv_files(source_folder, destination_folder)
# Out:
# Saved merged file: data/merged/csv\amcconfdiv2.csv
# Saved merged file: data/merged/csv\amlrconfdiv2.csv
# Saved merged file: data/merged/csv\dcconfdiv2.csv
# Saved merged file: data/merged/csv\dmconfdiv2.csv
# Saved merged file: data/merged/csv\fbconfdiv2.csv
# Saved merged file: data/merged/csv\gkconfdiv2.csv
# Saved merged file: data/merged/csv\mcconfdiv2.csv
# Saved merged file: data/merged/csv\mlrconfdiv2.csv
# Saved merged file: data/merged/csv\scconfdiv2.csv
# Saved merged file: data/merged/csv\wbconfdiv2.csv
